# %% [markdown]
# <h1>Sentiment Analysis for Funny Classification</h1>

# %% [markdown]
# Main idea is to extract words within brackets in the corpus and see if there is a way to use the output polarity score as a metric for how funny a sentence is in a transcript. Hypothesis: Polarity score for 'cheering' > 'laughing' > 'chuckling'.

# %% [markdown]
# We will be using the original `transcripts.csv`data in our sentiment analysis of the words in brackets, and rule-based approach is used as a preliminary data exploration step.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import pickle
import seaborn as sns
#from textblob import TextBlob
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#Load corpus
df = pd.read_csv('transcripts.csv')
df.head()
# Out:
#    Unnamed: 0         Comedian               Date  \
# 0           0       Chris Rock      March 8, 2023
# 1           1       Marc Maron      March 3, 2023
# 2           2  Chelsea Handler      March 3, 2023
# 3           3         Tom Papa      March 3, 2023
# 4           4    Jim Jefferies  February 22, 2023
#
#                                    Title  \
# 0  Selective Outrage (2023) | Transcript
# 1        Thinky Pain (2013) | Transcript
# 2          Evolution (2020) | Transcript
# 3        What A Day! (2022) | Transcript
# 4        High n’ Dry (2023) | Transcript
#
#                                             Subtitle  \
# 0                                                NaN
# 1  Marc Maron returns to his old stomping grounds...
# 2  Chelsea Handler is back and better than ever -...
# 3  Follows Papa as he shares about parenting, his...
# 4  Jim Jefferies is back and no topic is off limi...
#
#                                           Transcript
# 0  [slow instrumental music playing] [funk drums ...
# 1  [siren wailing] I don’t know what you were thi...
# 2  Join me in welcoming the author of six number ...
# 3  Premiered on December 13, 2022 Ladies and gent...
# 4  Please welcome to the stage, Jim Jefferies! He...

# %% [markdown]
# <h2>Data Exploration</h2>

# %% [markdown]
# <h3>Identify Inconsistencies in Context Annotations</h3>

# %% [markdown]
# Since we are analyzing the contexts within the square brackets, we need to check if the bracket punctuations are consistent.

# %%
def count_square_brackets(transcript):
    '''Naive way of checking for consistency - check if number of open brackets 
    and number of close brackets are the same.''' 
    
    open_brackets = transcript.count("[")
    close_brackets = transcript.count("]")
    
    if open_brackets == close_brackets:
        return open_brackets
    
    return -1

df_brackets = df.copy()
df_brackets['num_sqbrackets'] = df_brackets["Transcript"].map(count_square_brackets)

# Return the transcripts with inconsistent square brackets
print("Number of transcripts with inconsistent square brackets: ", len(df_brackets[df_brackets.num_sqbrackets == -1]))

# Return the transcripts with no square brackets
print("Number of transcripts with no square brackets: ", len(df_brackets[df_brackets.num_sqbrackets == 0]))
# Out:
# Number of transcripts with inconsistent square brackets:  9
# Number of transcripts with no square brackets:  166

# %% [markdown]
# We see that there are as many as 166 rows that there are no square brackets, though some of the transcripts use parentheses instead. We check for these in the next steps.

# %%
def count_round_brackets(transcript):
    '''Naive way of checking for consistency - check if number of open brackets 
    and number of close brackets are the same.''' 
    
    open_brackets = transcript.count("(")
    close_brackets = transcript.count(")")
    
    if open_brackets == close_brackets:
        return open_brackets
    
    return -1

df_brackets['num_rbrackets'] = df_brackets["Transcript"].map(count_round_brackets)

# Return the number of transcripts with inconsistent round brackets
print("Number of transcripts with inconsistent round brackets: ", len(df_brackets[df_brackets.num_rbrackets == -1]))

# Return the transcripts with no round brackets
print("Number of transcripts with no round brackets: ", len(df_brackets[df_brackets.num_rbrackets == 0]))
# Out:
# Number of transcripts with inconsistent round brackets:  6
# Number of transcripts with no round brackets:  318

# %%
# Return the transcripts with no round AND square brackets

print("Number of transcripts with no context annotations: ", len(df_brackets[(df_brackets.num_sqbrackets == 0) & (df_brackets.num_rbrackets == 0)]))
df_brackets[(df_brackets.num_sqbrackets == 0) & (df_brackets.num_rbrackets == 0)]
# Out:
# Number of transcripts with no context annotations:  114
#      Unnamed: 0           Comedian                Date  \
# 2             2    Chelsea Handler       March 3, 2023
# 3             3           Tom Papa       March 3, 2023
# 4             4      Jim Jefferies   February 22, 2023
# 14           14       Kate Berlant  September 24, 2022
# 27           27  Jerrod Carmichael        May 24, 2022
# ..          ...                ...                 ...
# 387         387         LOUIS C.K.         May 4, 2017
# 394         394      RICHARD PRYOR      April 26, 2017
# 401         401      GEORGE CARLIN      April 12, 2017
# 405         405       Eddie Murphy      April 11, 2017
# 406         406     Dave Chappelle      April 11, 2017
#
#                                                  Title  \
# 2                        Evolution (2020) | Transcript
# 3                      What A Day! (2022) | Transcript
# 4                      High n’ Dry (2023) | Transcript
# 14            Cinnamon in the Wind (2022) | Transcript
# 27                       Rothaniel (2022) | Transcript
# ..                                                 ...
# 387      LIVE AT  THE COMEDY STORE (2015) – Transcript
# 394  LIVE ON THE SUNSET STRIP (1982) – Full Transcript
# 401  JAMMING IN NEW YORK (1992) – Testo italiano co...
# 405                      Delirious (1983) – Transcript
# 406                The Age of Spin (2017) – Transcript
#
#                                               Subtitle  \
# 2    Chelsea Handler is back and better than ever -...
# 3    Follows Papa as he shares about parenting, his...
# 4    Jim Jefferies is back and no topic is off limi...
# 14   Kate Berlant performs an intimate, absurdist s...
# 27   Features Jerrod Carmichael in a standup comedy...
# ..                                                 ...
# 387  The comic puts his trademark hilarious/thought...
# 394  Comedy legend Richard Pryor touches on all sub...
# 401                                                NaN
# 405  Transcript of Eddie Murphy's 'Delirious', stan...
# 406  The Age of Spin: Dave Chappelle Live at the Ho...
#
#                                             Transcript  num_sqbrackets  \
# 2    Join me in welcoming the author of six number ...               0
# 3    Premiered on December 13, 2022 Ladies and gent...               0
# 4    Please welcome to the stage, Jim Jefferies! He...               0
# 14   Whoa! Okay, yeah. Good. Okay, don’t embarrass ...               0
# 27   Man… We were waiting for you. I’m happy you’re...               0
# ..                                                 ...             ...
# 387  Thank you. Oh. Oh, my God, you guys. Oh, my Go...               0
# 394  Recorded at the Circle Star Theater in San Car...               0
# 401  Ciao, grazie. Grazie. Grazie. Grazie molte. Gr...               0
# 405  Filmed on August 17, 1983 at DAR Constitution ...               0
# 406  This is Dave. He tells dirty jokes for a livin...               0
#
#      num_rbrackets
# 2                0
# 3                0
# 4                0
# 14               0
# 27               0
# ..             ...
# 387              0
# 394              0
# 401              0
# 405              0
# 406              0
#
# [114 rows x 8 columns]

# %%
# Union the unique transcripts with inconsistent square and round brackets

print("Number of transcripts with inconsistent square brackets OR inconsistent round brackets OR both: ", len(df_brackets[(df_brackets.num_sqbrackets == -1) | (df_brackets.num_rbrackets == -1)]))
df_brackets[(df_brackets.num_sqbrackets == -1) | (df_brackets.num_rbrackets == -1)]
# Out:
# Number of transcripts with inconsistent square brackets OR inconsistent round brackets OR both:  13
#      Unnamed: 0                 Comedian               Date  \
# 87           87            Hannah Gadsby       May 26, 2020
# 93           93                 LEE MACK        May 8, 2020
# 125         125          Tiffany Haddish   December 5, 2019
# 144         144                      NaN      July 14, 2019
# 185         185              Trevor Noah  November 21, 2018
# 236         236              GREG DAVIES     April 27, 2018
# 250         250             FRED ARMISEN  February 13, 2018
# 260         260             D.L. Hughley   January 19, 2018
# 270         270               BILL HICKS   January 12, 2018
# 310         310         Gabriel Iglesias   November 7, 2017
# 311         311         GABRIEL IGLESIAS   November 7, 2017
# 317         317  COMEDY CENTRAL PRESENTS   October 10, 2017
# 371         371               Tom Segura      June 30, 2017
#
#                                                  Title  \
# 87                         Douglas (2020) – Transcript
# 93             GOING OUT LIVE (2010) – FULL TRANSCRIPT
# 125                  Black Mitzvah (2019) – Transcript
# 144  Tom Segura Overdoses – This Is Not Happening [...
# 185                Son of Patricia (2018) – Transcript
# 236     YOU MAGNIFICENT BEAST (2018) – Full Transcript
# 250      STANDUP FOR DRUMMERS (2018) – Full Transcript
# 260                   Unapologetic (2007) – Transcript
# 270  LIVE AT LAFF STOP, AUSTIN, TX, AND COBBS, SAN ...
# 310                 Hot And Fluffy (2007) – Transcript
# 311  I’M NOT FAT … I’M FLUFFY (2009) – Full Transcript
# 317               DAVE ATTELL (1999) – Full Transcript
# 371              Completely Normal (2014) – Transcript
#
#                                               Subtitle  \
# 87   In her second Netflix special "Douglas", Hanna...
# 93   Lee Mack, star of BBC comedy shows 'Not Going ...
# 125  The comedy special for the comedian/actress wa...
# 144  Tom Segura returns home from college for the f...
# 185  Trevor Noah gets out from behind the "Daily Sh...
# 236  British comedian Greg Davies revisits terrifyi...
# 250  For an audience of drummers, comedian Fred Arm...
# 260  D.C., Hughley focuses on such topics as the da...
# 270  Well, folks, this is kind of a sentimental eve...
# 310  Gabriel Iglesias blends storytelling, sound ef...
# 311  Good-natured comedian Gabriel Iglesias riffs o...
# 317  Dave Attell (S02E07) is the seventh episode of...
# 371  Levelheaded stand-up Tom Segura shares offhand...
#
#                                             Transcript  num_sqbrackets  \
# 87   The following is the transcript of Hannah Gadb...              -1
# 93   This programme contains strong language [APPLA...              -1
# 125  [roaring cheers] [Haddish] People think they k...              -1
# 144  Episode aired 30 July 2013 This woman goes “He...              -1
# 185  A NETFLIX ORIGINAL COMEDY SPECIAL [distant tra...              -1
# 236  ♪ Now I’m not trying to be rude ♪ But, hey, pr...              51
# 250  [man] Drummers only tonight. Drummers only. No...              -1
# 260  [Audience cheering] (DL Hughley enters from st...             114
# 270  Recorded Live at Laff Stop, Austin, TX, and Co...               3
# 310  [Latino-style music] [audience cheering] (male...              -1
# 311  [energetic music] ♪ ♪ [cheers and applause] – ...              -1
# 317  Dave Attell (S02E07) is the seventh episode of...               1
# 371  Ladies and gentlemen, Tom Segura! [Cheers and ...              -1
#
#      num_rbrackets
# 87               0
# 93              -1
# 125              0
# 144              0
# 185              0
# 236             -1
# 250              1
# 260             -1
# 270             -1
# 310             -1
# 311              0
# 317             -1
# 371              0

# %%
# Return transcripts with less than or equal to X annotations each for rounded and square brackets

X = 20

print("Number of transcripts with annotations but <= 20: ", 
      len(df_brackets[((df_brackets.num_sqbrackets > 0) & (df_brackets.num_sqbrackets <= X)) & 
            ((df_brackets.num_rbrackets > 0) & (df_brackets.num_rbrackets <= X))]))
df_brackets[((df_brackets.num_sqbrackets > 0) & (df_brackets.num_sqbrackets <= X)) & 
            ((df_brackets.num_rbrackets > 0) & (df_brackets.num_rbrackets <= X))]
# Out:
# Number of transcripts with annotations but <= 20:  22
#      Unnamed: 0         Comedian               Date  \
# 31           31              NaN        May 2, 2022
# 47           47       Bo Burnham       June 1, 2021
# 86           86   BILLY CONNOLLY       May 27, 2020
# 102         102       DAVE ALLEN     April 30, 2020
# 105         105    George Carlin     April 13, 2020
# 120         120    Kevin Bridges  December 22, 2019
# 138         138   Dave Chappelle    August 26, 2019
# 153         153              NaN       May 18, 2019
# 184         184              NaN  November 27, 2018
# 221         221        Bill Burr       July 6, 2018
# 231         231              NaN       May 16, 2018
# 243         243      STEWART LEE      March 6, 2018
# 247         247       Chris Rock  February 17, 2018
# 262         262       Chris Rock   January 19, 2018
# 263         263      Stewart Lee   January 17, 2018
# 273         273  ELLEN DEGENERES   January 10, 2018
# 279         279      DYLAN MORAN    January 5, 2018
# 324         324              NaN    October 2, 2017
# 350         350              NaN    August 21, 2017
# 372         372    GEORGE CARLIN      June 29, 2017
# 400         400        BILL BURR     April 19, 2017
# 411         411              NaN      April 1, 2017
#
#                                                  Title  \
# 31   Trevor Noah at the White House Correspondents’...
# 47                          Inside (2021) – Transcript
# 86       HIGH HORSE TOUR LIVE (2016) – FULL TRANSCRIPT
# 102          FIRST DAY AT CATHOLIC SCHOOL [TRANSCRIPT]
# 105             The Indian Drill Sergeant – Transcript
# 120   A Whole Different Story (2015) – Full Transcript
# 138                Sticks & Stones (2019) – Transcript
# 153               Doug Stanhope on babies and abortion
# 184       Volker Pispers about USA (2004) – Transcript
# 221      The Philadelphia Incident (2006) – Transcript
# 231                       DOUG STANHOPE ON NATIONALISM
# 243              90s COMEDIAN (2006) – Full Transcript
# 247                 Bring the Pain (1996) – Transcript
# 262                   Never Scared (2004) – Transcript
# 263              Stand-Up Comedian (2005) – Transcript
# 273             THE BEGINNING (2000) – Full Transcript
# 279            LIKE, TOTALLY… (2006) – Full Transcript
# 324  JIM JEFFERIES E IL CONTROLLO DELLE ARMI IN AME...
# 350      George Carlin at USC (1977) – Full Transcript
# 372          CARLIN ON CAMPUS (1984) – Full Transcript
# 400                      LET IT GO (2010) – TRANSCRIPT
# 411     Jim Jefferies on Gun Control [Full Transcript]
#
#                                               Subtitle  \
# 31   Trevor Noah headlined the annual White House C...
# 47   'Inside' carries satire, social commentary and...
# 86   Billy may had some tougher times in recent yea...
# 102  Dave Allen on his first day at Catholic school...
# 105  In 1965 “The Indian Sergeant,” was emerging as...
# 120                                                NaN
# 138  Legendary comedian Dave Chappelle is back with...
# 153  There's a specific group of over four million ...
# 184  Last part of Volker Pispers' program "Bis neul...
# 221  Transcript of the "Philadelphia incident" wher...
# 231  Nationalism does nothing but teach you to hate...
# 243  The Catholic Church are very worried about you...
# 247  In his second HBO stand-up special Chris Rock ...
# 262  The number one reason people hate America, the...
# 263  English stand-up comedian Stewart Lee stands i...
# 273  talks about everything from the world of insec...
# 279  Acerbic, eternally world-weary comic in stand ...
# 324  Il comico australiano Jim Jefferies ridicolizz...
# 350  George Carlin's first ever comedy special, fil...
# 372  Full transcript of 'Carlin on Campus', 10th al...
# 400  Burr's special 'Let it Go', recorded at The Fi...
# 411  Australian comedian Jim Jefferies breaks down ...
#
#                                             Transcript  num_sqbrackets  \
# 31   Great. I got a promise I will not be going to ...              12
# 47   Exploring mental health decline over 2020, the...               5
# 86   Ladies and gentlemen, would you please welcome...               1
# 102  Dave Allen on his first day at Catholic school...               3
# 105  In 1965 “The Indian Sergeant,” was emerging as...               1
# 120  Ladies and gentlemen, please welcome Kevin Bri...               6
# 138  Sticks & Stones is Dave Chappelle’s fifth Netf...               1
# 153  From “Dead Beat Hero” (2004) Immigration. Ther...               5
# 184  Last part of Volker Pispers’ program “Bis neul...               7
# 221  NEW!  The full transcript of Bill’s monologue ...               9
# 231  From No Refunds, recorded at the Gotham Comedy...               5
# 243  Recorded on 10 March 2006 at Chapter Arts, Can...               8
# 247  [Announcer] Live from the Takoma Theatre in Wa...               3
# 262  Chris Rock pulls out all the stops in his no-h...               1
# 263  Recorded on 10 March 2005 at The Stand, Glasgo...              10
# 273  Ladies and gentlemen, please, welcome Ellen De...               3
# 279  Ladies and gentlemen, please welcome to the st...               1
# 324  Il comico australiano Jim Jefferies ridicolizz...               1
# 350  Good evening, I’m Shana Alexander. Home Box Of...               1
# 372  [School bell] Welcome to the home of the class...               1
# 400  [Quirky rock music] All right. Thank you. Than...               6
# 411  Australian comedian Jim Jefferies breaks down ...              15
#
#      num_rbrackets
# 31               2
# 47               1
# 86               1
# 102              1
# 105              2
# 120              1
# 138              1
# 153              1
# 184              4
# 221              1
# 231              1
# 243              2
# 247             11
# 262              2
# 263              1
# 273              1
# 279             19
# 324              1
# 350              8
# 372              4
# 400              1
# 411              1

# %% [markdown]
# From the above, we have three problems with our data:
#
# 1. Lack of context annotations i.e. transcripts with no annotations (114 transcripts)
# 2. Inconsistent square/round brackets (13 transcripts)
# 3. Transcripts with very few annotations i.e. <= 20 (22 transcripts)
#
# Assuming transcripts for each category are unique, there is a maximum of 149 transcripts that we are potentially leaving out of the dataset, leaving us with roughly 2/3 of the data. (Will this affect our analysis greatly?)
#
# We remove the transcripts with no annotations from our corpus. This will skew our classification results to classifying potentially funny content to being unfunny due to the lack of annotations in the transcripts.
#
# For the remaining problematic scripts, it may still be possible to handle the data such that more comedy segments can be added to the corpus for which the brackets are consistent. However, for our baseline model, we will try to remove these scripts first.

# %%
# Filter problematic transcripts and remove them from our dataset

df_no_annotations = df_brackets[(df_brackets.num_sqbrackets == 0) & (df_brackets.num_rbrackets == 0)]
df_inconsistent = df_brackets[(df_brackets.num_sqbrackets == -1) | (df_brackets.num_rbrackets == -1)]
df_few_annotations = df_brackets[((df_brackets.num_sqbrackets > 0) & (df_brackets.num_sqbrackets <= X)) & 
                        ((df_brackets.num_rbrackets > 0) & (df_brackets.num_rbrackets <= X))]

def populate_removed_idx():
    no_annotations_idx = df_no_annotations.index
    inconsistent_idx = df_inconsistent.index
    few_annotations_idx = df_few_annotations.index
    
    newList = list(set().union(no_annotations_idx, inconsistent_idx, few_annotations_idx))
    return newList
                   
removed_idx = populate_removed_idx() # Store removed indices

df_clean = df.copy().drop(index = removed_idx) # Drop problematic indices
df_clean.head()
# df_clean.shape #266 transcripts
# Out:
#    Unnamed: 0          Comedian               Date  \
# 0           0        Chris Rock      March 8, 2023
# 1           1        Marc Maron      March 3, 2023
# 5           5               NaN   January 22, 2023
# 6           6    Dave Chappelle   January 22, 2023
# 7           7  Iliza Shlesinger  December 20, 2022
#
#                                                Title  \
# 0              Selective Outrage (2023) | Transcript
# 1                    Thinky Pain (2013) | Transcript
# 5  Dave Chappelle Stand-Up Monologue – SNL (2022)...
# 6               What’s in a Name (2022) | Transcript
# 7                    Hot Forever (2022) | Transcript
#
#                                             Subtitle  \
# 0                                                NaN
# 1  Marc Maron returns to his old stomping grounds...
# 5  Dave Chappelle talks about Kanye West, the 202...
# 6  Dave Chappelle delivers a speech at his presti...
# 7  With topics ranging from tight rompers to ugly...
#
#                                           Transcript
# 0  [slow instrumental music playing] [funk drums ...
# 1  [siren wailing] I don’t know what you were thi...
# 5  Original air date: November 12, 2022 * * * Lad...
# 6  What’s in a Name? is a 40-minute talk Chappell...
# 7  [upbeat music playing] [crowd cheering] Clevel...

# %%
# Filter transcripts with no comedian

no_comedian_idx = df_clean[df_clean["Comedian"].isna()].index
#len(no_comedian_idx) #20 transcripts without comedian
clean_transcripts = df_clean.drop(index = no_comedian_idx)
clean_transcripts.head()
#clean_transcripts.shape # 246 transcripts
# Out:
#    Unnamed: 0          Comedian               Date  \
# 0           0        Chris Rock      March 8, 2023
# 1           1        Marc Maron      March 3, 2023
# 6           6    Dave Chappelle   January 22, 2023
# 7           7  Iliza Shlesinger  December 20, 2022
# 8           8  Gabriel Iglesias  November 28, 2022
#
#                                    Title  \
# 0  Selective Outrage (2023) | Transcript
# 1        Thinky Pain (2013) | Transcript
# 6   What’s in a Name (2022) | Transcript
# 7        Hot Forever (2022) | Transcript
# 8     Stadium Fluffy (2022) | Transcript
#
#                                             Subtitle  \
# 0                                                NaN
# 1  Marc Maron returns to his old stomping grounds...
# 6  Dave Chappelle delivers a speech at his presti...
# 7  With topics ranging from tight rompers to ugly...
# 8  Features Gabriel "Fluffy" Iglesias as he talks...
#
#                                           Transcript
# 0  [slow instrumental music playing] [funk drums ...
# 1  [siren wailing] I don’t know what you were thi...
# 6  What’s in a Name? is a 40-minute talk Chappell...
# 7  [upbeat music playing] [crowd cheering] Clevel...
# 8  [man] Can you please state your name? Martin M...

# %% [markdown]
# <h3>Split Sentences and Annotations</h3>

# %%
# Select a sample transcript from the cleaned transcripts

sample_transcript = clean_transcripts.loc[0, "Transcript"]
sample_title = clean_transcripts.loc[0, "Title"]

print("Transcript:\n", sample_transcript)
print("Title:\n", sample_title)
# Out:
# Transcript:
#  [slow instrumental music playing] [funk drums playing] [indistinct chatter] [man] Let’s go! [hip-hop music playing] [audience cheering] [Chris Rock] She said, “$300, I’ll do anything you want.” I said, “Bitch, paint my house.” We don’t need the death penalty! We got the tossed salad man! ‘Cause if a bullet costs $5,000, there’ll be no more innocent bystanders. I ain’t scared of Al-Qaeda. I’m scared of Al-Cracker. You cannot lend money to people you’re fucking. ‘Cause they think that sex is a payback. We just got a few bad apples that like to crash into mountains. [audience laughing] [audience cheering] [hip-hop music playing] [female announcer] Ladies and gentlemen. Ladies and gentlemen. Chris Rock! [audience cheering] [audience continue cheering] [Chris Rock] What’s up, Baltimore? [audience cheers loudly] Yes! Yes, yes. Thank you! Thank you so much! Thank you so much to coming to my Netflix special. Thank you. [audience cheering] That’s right. That’s right! Okay. I’mma try to do a show. [man shouting unintelligibly] I’mma try… N*gga, sit down! I’mma try to do a show tonight without offending nobody, okay? I’mma try my best. You know why? ‘Cause you never know who might get triggered. That’s right. You say the wrong thing… motherfuckers get scared. You gotta watch out. You know what people say. They always say, uh, “words hurt.” That’s what they say. You gotta watch what you say. ‘Cause words hurt. You know anybody that says words hurt has never been punched in the face. [audience laughing] Okay? Yeah, words hurt when you write them on a brick, okay? You gotta watch out. Everybody’s scared. Everybody scared. If you a certain age and you go to work, you are fucking scared. In the old days, if somebody wanted your job, they just worked harder than you. Now, somebody wants your job, they just wait for you to say some dumb shit. Yeah. Try to get you with one of them woke traps. Say, “Hey, we going to a gay wedding tomorrow.” “How do you feel about that?” Oh, ho, ho, ho! “It’s good. It’s good.” Don’t fall into the woke trap at all now. I have no problem with the wokeness. I have no problem with it at all. I’m all for social justice. I’m all for, for marginalized people getting their rights. The thing I have a problem with is the selective outrage. [audience applauding]    That’s right, selective outrage. Everybody, you know what I’m talking about? One person does something, they get cancelled. Somebody else does the exact same thing… No. You know what I’m talking about. You know, like the kind of people that play Michael Jackson songs, but won’t play R. Kelly. [audience laughing and applauding] [imperceptible] Same crime. One of them just got better songs. [chuckling] That’s right. Well, I’ll play “Startin’ Somethin’,” it’s a party. I play “Bump n’ Grind,” now you are activists. So, everybody’s scared. Everybody full of shit, you know? I’m in my old neighborhood the other day. I bumped into my, my good friend, Fred. Hadn’t seen him in years. Hadn’t seen him in years. Fred got a new job at AT&T, okay? So, I’m like, “Hey, Fred, how’s the job?” And Fred’s like, “Oh, I love the job.” “It’s a safe space.” “I feel seen, I feel heard.” “There’s a lot of diversity.” And I’m looking at him. I’m like… “N*gga, it’s me.” What, you think I’m wearing a wire or some shit? What the fuck you talking about, safe space? N*gga, you did eight years for manslaughter. Nobody’s safe around you. Everybody’s full of shit. Motherfuckers typing out woke ass tweets on a, on a phone made by child slaves. You need to cut it out, man. Not only is everybody full of shit, not only is everybody full of shit, every business is full of shit. – [man whooping] Everybody you do business, they don’t even tell you about the product no more. They just tell you how much charity they do. They say, “We give back.” “We like to give back.” “We don’t even like the money.” “We just give back.” I’m in the mall the other day. I went by that store. What’s this thing? A Lululemon. Lu ...
# Title:
#  Selective Outrage (2023) | Transcript

# %%
# Combine annotations if they are next to each other
def combine_annotations(transcript):
    word_split = transcript.split(" ")
    
    words_w_annot = []
    curr_idx = 0
    annot_prev = False #True if previous index is annotation
    while curr_idx < len(word_split):
        word = word_split[curr_idx]
        
        if word.startswith("["):
            #Append with other words within the brackets
            annot_split = [word]
            while not word_split[curr_idx].endswith("]"):
                curr_idx += 1
                annot_split.append(word_split[curr_idx])
                
            result = " ".join(annot_split) #e.g. [audience laughs]
            
            #If the previous word is an annotation
            if annot_prev:
                prev = words_w_annot.pop() #Get the previous annotation
                new_annot = prev + result # e.g. [audience laughs][audience continues laughing]
                result = new_annot.replace("][", "; ")
            
            #Append result to stored words and annotations list
            words_w_annot.append(result)
            annot_prev = True            
        else:
            words_w_annot.append(word_split[curr_idx])
            annot_prev = False
            
        curr_idx += 1
    
    return " ".join(words_w_annot)
        
            
#Testing function
print(combine_annotations("[audience laughs] [audience cries] Hello everybody!")) #['[audience laughs; audience cries]']
# Out:
# [audience laughs; audience cries] Hello everybody!

# %%
# Let annotations be at the front of each sentence
def reorganise_transcript(transcript):
    combined_annot = combine_annotations(transcript)
    return [ sentence.strip() + "]" for sentence in combined_annot.split("]") if sentence != ""]  

def extract_features_labels(transcript):
    reorged = reorganise_transcript(transcript)
    
    annot_script = [sentence.split("[") for sentence in reorged]
    script = [pair[0].strip() for pair in annot_script]
    annots = [pair[1][:-1] for pair in annot_script]
    
    return pd.DataFrame(zip(script, annots), columns = ["Script", "Annotation"])

sample_data = extract_features_labels(sample_transcript)

#Remove sentences with no script or annotation
sample_data_cleaned = sample_data[(sample_data["Script"] != "") & (sample_data["Annotation"] != "")]
sample_data_cleaned
# Out:
#                                                Script  \
# 1                                           Let’s go!
# 2   She said, “$300, I’ll do anything you want.” I...
# 3   Ladies and gentlemen. Ladies and gentlemen. Ch...
# 4                               What’s up, Baltimore?
# 5   Yes! Yes, yes. Thank you! Thank you so much! T...
# ..                                                ...
# 86  No. It’s never gonna happen. No. Fuck that shi...
# 87  I took it like motherfucking Pacquiao, okay? S...
# 88  Pookie, motherfucker. I played a piece of corn...
# 89  I didn’t. I did not have any entanglement. For...
# 90  That’s what the fuck happened, okay? Get the f...
#
#                                            Annotation
# 1   hip-hop music playing; audience cheering; Chri...
# 2   audience laughing; audience cheering; hip-hop ...
# 3   audience cheering; audience continue cheering;...
# 4                              audience cheers loudly
# 5                                   audience cheering
# ..                                                ...
# 86                                  audience cheering
# 87                                  audience cheering
# 88                                  audience cheering
# 89                                  audience cheering
# 90  slams mic; audience cheering and applauding; h...
#
# [90 rows x 2 columns]

# %% [markdown]
# <h3>Sentiment Analysis of Annotations (Label)</h3>

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\faith\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\faith\anaconda3\lib\site-packages (from textblob) (3.6.1)
# Requirement already satisfied: tqdm in c:\users\faith\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.59.0)
# Requirement already satisfied: joblib in c:\users\faith\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.0.1)
# Requirement already satisfied: click in c:\users\faith\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: regex in c:\users\faith\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import string 
from textblob import TextBlob

# %%
def clean_text(text) :
    '''Make text lowercase, remove text in square brackets, remove punctuations, 
    remove quotation marks, remove words containing numbers, remove \n'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)   
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text) 
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    
    return text

cleaning = lambda x : clean_text(x)

# %%
# apply data cleaning to Annotation column 
label_data = sample_data_cleaned.copy()
label_data['Annotation'] = label_data['Annotation'].apply(cleaning)

label_data.head()
# Out:
#                                               Script  \
# 1                                          Let’s go!
# 2  She said, “$300, I’ll do anything you want.” I...
# 3  Ladies and gentlemen. Ladies and gentlemen. Ch...
# 4                              What’s up, Baltimore?
# 5  Yes! Yes, yes. Thank you! Thank you so much! T...
#
#                                           Annotation
# 1  hiphop music playing audience cheering chris rock
# 2  audience laughing audience cheering hiphop mus...
# 3  audience cheering audience continue cheering c...
# 4                             audience cheers loudly
# 5                                  audience cheering

# %% [markdown]
# <h4>Rule-based Approach</h4>

# %%
# lambda functions for TextBlob to find polarity and subjectivity of each transcript 
pol = lambda x: TextBlob(x).sentiment.polarity

# %%
df_textblob = label_data.copy()

# %%
# get the polarity and subjectivity score of each transcript 
df_textblob['Polarity_Score'] = df_textblob['Annotation'].apply(pol)

# %%
df_textblob
# Out:
#                                                Script  \
# 1                                           Let’s go!
# 2   She said, “$300, I’ll do anything you want.” I...
# 3   Ladies and gentlemen. Ladies and gentlemen. Ch...
# 4                               What’s up, Baltimore?
# 5   Yes! Yes, yes. Thank you! Thank you so much! T...
# ..                                                ...
# 86  No. It’s never gonna happen. No. Fuck that shi...
# 87  I took it like motherfucking Pacquiao, okay? S...
# 88  Pookie, motherfucker. I played a piece of corn...
# 89  I didn’t. I did not have any entanglement. For...
# 90  That’s what the fuck happened, okay? Get the f...
#
#                                            Annotation  Polarity_Score
# 1   hiphop music playing audience cheering chris rock             0.0
# 2   audience laughing audience cheering hiphop mus...             0.0
# 3   audience cheering audience continue cheering c...             0.0
# 4                              audience cheers loudly             0.1
# 5                                   audience cheering             0.0
# ..                                                ...             ...
# 86                                  audience cheering             0.0
# 87                                  audience cheering             0.0
# 88                                  audience cheering             0.0
# 89                                  audience cheering             0.0
# 90  slams mic audience cheering and applauding hip...             0.0
#
# [90 rows x 3 columns]

# %%
sentence = ["audience cheering"]

df_test = pd.DataFrame(sentence)
df_test[0].apply(pol)
# Out:
# 0    0.0
# Name: 0, dtype: float64

# %% [markdown]
# Polarity score is dependent on how much emotion is used in the sentence. As "audience cheering" is a fact/narration, there is no emotion detected in the context annotation.

# %% [markdown]
# <h3>Assign Binary Label</h3>

# %%
df_labelled = sample_data_cleaned.copy()

# Label laughter if there is the word "laugh" in the annotation
annots = list(df_labelled["Annotation"])
labels = [False for _ in range(len(annots))]
for idx in range(len(annots)):
    laughter = "laugh" in annots[idx].lower()
    labels[idx] = laughter

df_labelled["Label"] = labels
df_labelled.head()
# Out:
#                                               Script  \
# 1                                          Let’s go!
# 2  She said, “$300, I’ll do anything you want.” I...
# 3  Ladies and gentlemen. Ladies and gentlemen. Ch...
# 4                              What’s up, Baltimore?
# 5  Yes! Yes, yes. Thank you! Thank you so much! T...
#
#                                           Annotation  Label
# 1  hip-hop music playing; audience cheering; Chri...  False
# 2  audience laughing; audience cheering; hip-hop ...   True
# 3  audience cheering; audience continue cheering;...  False
# 4                             audience cheers loudly  False
# 5                                  audience cheering  False

# %% [markdown]
# <h3>Text Pre-processing</h3>

# %%
import re
import string 
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer 
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def clean_text(text) :
    '''Make text lowercase, remove text in square brackets, remove punctuations, 
    remove quotation marks, remove words containing numbers, remove \n'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)   
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text) 
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    
    return text

cleaning = lambda x : clean_text(x)

# %%
# apply data cleaning to Annotation column 

df_processed = df_labelled.copy()
df_processed['Script'] = df_processed['Script'].apply(cleaning)

# %%
df_processed.head()
# Out:
#                                               Script  \
# 1                                            lets go
# 2  she said  ill do anything you want i said bitc...
# 3  ladies and gentlemen ladies and gentlemen chri...
# 4                                 whats up baltimore
# 5  yes yes yes thank you thank you so much thank ...
#
#                                           Annotation  Label
# 1  hip-hop music playing; audience cheering; Chri...  False
# 2  audience laughing; audience cheering; hip-hop ...   True
# 3  audience cheering; audience continue cheering;...  False
# 4                             audience cheers loudly  False
# 5                                  audience cheering  False

# %%
# Helper functions to create tokenizer for TF-IDF Vectorize

def get_wordnet_pos(treebank_tag) : 
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        # As default pos in lemmatization is Noun
        return wordnet.NOUN
    
lemmatizer = WordNetLemmatizer()

def pos_then_lemmatize(pos_tagged_words) :
    res = []
    for pos in pos_tagged_words : 
        word = pos[0]
        pos_tag = pos[1]

        lem = lemmatizer.lemmatize(word, get_wordnet_pos(pos_tag))
        res.append(lem)
    return res

def custom_tokenizer(text) : 
    words = word_tokenize(text.lower())
    
    stop_words = set(stopwords.words('english')) 
    filtered_words = [w for w in words if not w in stop_words] 
    pos_tagged_words = nltk.pos_tag(filtered_words)
    tokens = pos_then_lemmatize(pos_tagged_words)
    
    return tokens

# %%
# TF-IDF Vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer(ngram_range = (1, 1),
                    tokenizer = custom_tokenizer)
tf_vectors = tf.fit_transform(df_labelled['Script'])
tf_feature_names = tf.get_feature_names_out()
tfidf_matrix = pd.DataFrame(tf_vectors.toarray(), columns=tf_feature_names)
tfidf_matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3af6d7f39524> in <module>
#       3
#       4 tf = TfidfVectorizer(ngram_range = (1, 1),
# ----> 5                     tokenizer = custom_tokenizer)
#       6 tf_vectors = tf.fit_transform(df_labelled['Script'])
#       7 tf_feature_names = tf.get_feature_names_out()
#
# NameError: name 'custom_tokenizer' is not defined

# %%
conda update -n base -c defaults conda
